# %% [markdown]
# # ID408B. Mid-term Exam
# ## Part 1. Knowledge Check
# - Exam Hour: 2021.10.21  7:00pm - 7:30pm
# - Submit the completed file on KLMS (https://klms.kaist.ac.kr/mod/assign/view.php?id=614717)
# - You can get max. 37pts, which will be scaled up to 50pts before merging with the other parts.
#
# ### Instruction
# - Same as the assignments, carefully read cells containing "# QUESTION IN THIS CELL #"
# - In those cells, you must complete certain variables / methods / cell following the instruction.
# - This is open book / open Internet. You can open any PDF or websites including the lecture notes
# - Never communicate with other students
# ---

# %% [markdown]
# ### Question 1. Determine whether each statement is True or False (7pts)
# (according the lectures, tutorials, and assignments)

# %%
# QUESTIONS IN THIS CELL #
# S1. CSV and JSON are file formats of plain text that contains structured information.
answer_q1_s1 = True  # True if the above statement is correct, otherwise False

# S2. CSV represents tabular data that has rows and columns, while JSON represents hierarchical
#         data that consists of key and value pairs.
answer_q1_s2 = None  # True if the above statement is correct, otherwise False

# S3. Pivot and Roll-up are techniques to convert CSV to JSON (and vice versa). 
answer_q1_s3 = None  # True if the above statement is correct, otherwise False

# S4. CSV is usually loaded as nested-list, JSON is loaded as Python dictionary object.
answer_q1_s4 = None  # True if the above statement is correct, otherwise False

# S5. JSON is often considered to be more flexible than CSV, 
#        since its value can hold either a boolean, text, number, list, or even dictionary.  
answer_q1_s5 = None  # True if the above statement is correct, otherwise False

# S6. CSV is ready to train machine learning models, 
#        since each row corresponds to a feature set or labels to predict.
answer_q1_s6 = None  # True if the above statement is correct, otherwise False

# S7. Items in Python dictionary are not ordered. In order to sort, 
#        we usually convert a dictionary to a list of items.
answer_q1_s7 = None  # True if the above statement is correct, otherwise False

# %% [markdown]
# ### Question 2. Design JSON structure for a specific purpose (5pts)
# Assume that you have the CSV shown below that contains customer behaviors in a grocery store.
# ![image.png](attachment:1e58ca9a-675a-4069-a35b-fd0e171cff33.png)

# %% [markdown]
# - Design a JSON structure that contains the following information (without additional computation):
#     - How many times each action type occurred within each product category
#     - List of customers who purchased items in each category

# %%
# QUESTIONS IN THIS CELL #
### Replace the following python dictionary to answer the above questions ### 
answer_q2 = {
    # FILL THIS DICTIONARY
}

# %% [markdown]
# ---
# ### Question 3. Levels of Measurement and Visual Encoding (9pts)
# Determine whether each pair of dataset and chart violates any rule of levels of measurement and/or the cheatsheet of visual encoding. If it violates, briefly describe why it violates and how to fix (in 200 characters).

# %% [markdown]
# #### Case A. Professor Ratings
# The dataset is five-axis ratings of two professors.
# ![image.png](attachment:cf919a5c-3737-4fa3-aa65-3ff43988f632.png)

# %%
# QUESTION IN THIS CELL #
answer_q3_A = None  # True if the chart is appropriate in terms of 
                    # levels of measurement and visual encoding,
                    # False if the chart is not appropriate
answer_q3_A_describe = "WHY IT VIOLOATES AND HOW TO FIX"   # If you answered False for the above 
                                # question, briefly describe why and how to fix 
                                # (within 200 characters)

# %% [markdown]
# ---
# #### Case B. Study hours and Letter grades
# The following chart shows a linear correlation between study hours (how many hours each student study) and letter grades.
# ![image.png](attachment:5df78010-e7f4-4f72-8351-3f6195856386.png)

# %%
# QUESTION IN THIS CELL #
answer_q3_B = None  # True if the chart is appropriate in terms of 
                    # levels of measurement and visual encoding,
                    # False if the chart is not appropriate
answer_q3_B_describe = "WHY IT VIOLOATES AND HOW TO FIX"   # If you answered False for the above 
                                # question, briefly describe why and how to fix 
                                # (within 200 characters)

# %% [markdown]
# ---
# #### Case C. Temperatures of Closed or Open Window
# The dataset is room temperatures with the window open or closed
# ![image.png](attachment:54cf9058-9a14-48e8-997d-d62af39c79c6.png)

# %%
# QUESTION IN THIS CELL #
answer_q3_C = None  # True if the chart is appropriate in terms of 
                    # levels of measurement and visual encoding,
                    # False if the chart is not appropriate
answer_q3_C_describe = "WHY IT VIOLOATES AND HOW TO FIX"   # If you answered False for the above 
                                # question, briefly describe why and how to fix 
                                # (within 200 characters)

# %% [markdown]
# ---
# ### Question 4. Chart Efficacy for Communicating Insights (8pts)
# Improve the below charts shown below - focusing on whether the chart effectively communicates the corresponding findings. If it violates, briefly describe how to fix (in 200 characters).

# %% [markdown]
# ---
# #### Case A. Body Measure of Penguines on Three Islands
# Findings.
# - "Penguines on Biscoe island has larger culmin lengths than penguines on other two islands."
# ![image.png](attachment:0f4fd452-b716-426b-b9c7-f51aa298df0a.png)

# %%
# QUESTION IN THIS CELL #
answer_q4_A = None  # True if the chart is effective at communicating the finding
                    # False if the chart is not effective
answer_q4_A_describe = "WHY IT VIOLOATES AND HOW TO FIX"   # If you answered False for the above 
                                # question, briefly describe why and how to fix 
                                # (within 200 characters)

# %% [markdown]
# ---
# #### Case B. Sales of Sweet Treats in Three Cities
# Findings.
# - "Biscuit is the best selling item in the overall sales."
# ![image.png](attachment:20b5d89f-3325-40d4-8b97-491c30075bf9.png)

# %%
# QUESTION IN THIS CELL #
answer_q4_B = None  # True if the chart is effective at communicating the finding
                    # False if the chart is not effective
answer_q4_B_describe = "WHY IT VIOLOATES AND HOW TO FIX"   # If you answered False for the above 
                                # question, briefly describe why and how to fix 
                                # (within 200 characters)

# %% [markdown]
# ### Question 5. Determine whether each statement is True or False (8pts)
# (according the lectures, tutorials, and assignments)

# %%
# QUESTIONS IN THIS CELL #
# S1. The most important goal of interactivity is to make data visualization memorable.
answer_q5_s1 = None  # True if the above statement is correct, otherwise False

# S2. A good visualization should be able to cover a wide range of tasks. 
answer_q5_s2 = None  # True if the above statement is correct, otherwise False

# S3. Brush & Linking is a common technique for zooming and filtering. 
answer_q5_s3 = None  # True if the above statement is correct, otherwise False

# S4. A chart in 3D space (i.e. x,y,z axis) is a bad design choice for scientific visualizations
answer_q5_s4 = None  # True if the above statement is correct, otherwise False

# S5. Data table is a good way to show the overview of dataset.
answer_q5_s5 = None  # True if the above statement is correct, otherwise False

# S6. Entertaining the audience is one of the best ways to make your story more believable. 
answer_q5_s6 = None  # True if the above statement is correct, otherwise False

# S7. Finding novel insights is not the main purpose of data storytelling. 
answer_q5_s7 = None  # True if the above statement is correct, otherwise False

# S8. Tufte's Data-Ink ratio rule may not apply to some products and services.  
answer_q5_s8 = None  # True if the above statement is correct, otherwise False
