# %% [markdown]
# # Week 9-10 Assignments
# From this assignment we merged the two parts (knowledge check and coding exercise) into a section for regular questions. Questions in the section will be scaled to total 100 pts. There is an extra (previously called "challenge") question at the end, which is worth 25% of the regular questions.
#
# ## How to Make Your Answers
# - You must carefully read cells containing "# QUESTION IN THIS CELL #". In those cells, you must complete certain variables / methods / cell following the instruction.
# - If you have any question or found bugs, please post it on the Q&A board of KLMS or send me an email (takyeonlee@kaist.ac.kr).
#
# ## Make sure your notebook runs without error
# - After finishing the entire notebook, use (Kernel > Restart Kernel and Run All Cells) and __make sure all the cells run without any syntax error__.

# %% [markdown]
# ---
# ## Part 1. Regular Questions (100pts)
# - Now part 1 covers both knowledge check and coding exercise.
# - Before answering these questions, make sure you watched the corresponding lecture and tutorial videos.
# - Carefully read questions in comments, and put your answers in `answer_N` variables (where N=0,1,2,...).

# %% [markdown]
# ### Probability

# %%
# QUESTION IN THIS CELL #
''' Question 1-10. Indicate whether the following statements are True or False  '''

# STATEMENT.  P(X) = Frequency of the event X divided by # overall observations
answer_1 = None # Replace None with True or False

# STATEMENT.  P(X) + P(not X) = 1
answer_2 = None # Replace None with True or False

# STATEMENT.  P(X,Y) means the probability of observing Y strictly after observing X
#             Therefore P(X,Y) and P(Y,X) may not be the same
answer_3 = None # Replace None with True or False

# STATEMENT.  P(X) + P(Y) means the probability of observing event X or Y 
#             assuming that X and Y cannot happen at the same time
answer_4 = None # Replace None with True or False

# STATEMENT.  P(X|Y) means the probability of observing Y given that you observed the event X
answer_5 = None # Replace None with True or False

# STATEMENT.  For P(X|Y), event Y must occur before X happening.
answer_6 = None # Replace None with True or False

# STATEMENT.  Marginal probability focuses on the event only ignoring other variables. 
#             For instance, P(X) does not change if P(Y|X) changes
answer_7 = None # Replace None with True or False

# STATEMENT.  Joint probability and Compound probability are the same thing 
answer_8 = None # Replace None with True or False

# STATEMENT.  Joint probability P(X,Y) can be calculated from P(X|Y) * P(Y)
#             and there is another path to get the same result P(Y|X) * P(X)
answer_9 = None # Replace None with True or False

# STATEMENT.  P(X|Y) and P(Y|X) always have the same value
answer_10 = None # Replace None with True or False

# %% [markdown]
# ### Bayes Theorem

# %% [markdown]
# #### Question 11-18. For the given contingency table, calculate the following probabilities
# |                      | Spam | Not Spam | All |
# |----------------------|------|----------|-----|
# | Contains 'offer'     | 24   | 7        | 31  |
# | Not contains 'offer' | 6    | 63       | 69  |
# | All                  | 30   | 70       | 100 |

# %%
# QUESTION IN THIS CELL #

''' What is the probability of containing 'offer' for spam emails? '''
answer_11 = None # Replace None with a decimal number (e.g. 0.33) or formula (e.g. 2/32)

''' What is the probability of not containing 'offer' for regular (non-spam) emails? '''
answer_12 = None # Replace None with a decimal number (e.g. 0.33) or formula (e.g. 2/32)

''' What is the probability of an email to be a spam if it contains 'offer'? '''
answer_13 = None # Replace None with a decimal number (e.g. 0.33) or formula (e.g. 2/32)

''' What is the probability of an email to be a regular (non-spam) email if it does not 'offer'? '''
answer_14 = None # Replace None with a decimal number (e.g. 0.33) or formula (e.g. 2/32)

''' What is the probability of an email to be either a spam or a non-spam email?'''
answer_15 = None # Replace None with a decimal number (e.g. 0.33) or formula (e.g. 2/32)

''' Let's say we apply a heuristic rule (if an email is a spam if and only if it contains 'offer')
    What is the probability of this rule works correctly?
'''
answer_16 = None # Replace None with a decimal number (e.g. 0.33) or formula (e.g. 2/32)

''' For the above heuristic, what is the probability of the rule making false positive cases
    (i.e. putting a non-spam email to the spam folder)  
'''
answer_17 = None # Replace None with a decimal number (e.g. 0.33) or formula (e.g. 2/32)

''' For the above heuristic, what is the probability of the rule making false negative cases
    (i.e. putting a spam email to the regular inbox)  
'''
answer_18 = None # Replace None with a decimal number (e.g. 0.33) or formula (e.g. 2/32)

# %% [markdown]
# ### Movie Dataset
# To see whether movie budgets and revenues are correlated, we will use the movie dataset from [kaggle](https://www.kaggle.com/stephanerappeneau/350-000-movies-from-themoviedborg?select=AllMoviesDetailsCleaned.csv). Follow the below steps.

# %%
import pandas as pd
# We will read the dataset using special separator ";". It also requires large memory.
df_movies = pd.read_csv("movies.csv", sep=";", low_memory=False)

# %%
df_movies.columns  # You can easily check the column titles
# Out:
# Index(['id', 'budget', 'genres', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'production_companies_number',
#        'production_countries_number', 'spoken_languages_number'],
#       dtype='object')

# %%
df_movies.head(5)  # Preview the first five records
# Out:
#    id   budget                 genres    imdb_id original_language  \
# 0   2        0            Drama|Crime  tt0094675                fi
# 1   3        0           Drama|Comedy  tt0092149                fi
# 2   5  4000000           Crime|Comedy  tt0113101                en
# 3   6        0  Action|Thriller|Crime  tt0107286                en
# 4   8    42000            Documentary  tt0825671                en
#
#                      original_title  \
# 0                             Ariel
# 1              Varjoja paratiisissa
# 2                        Four Rooms
# 3                    Judgment Night
# 4  Life in Loops (A Megacities RMX)
#
#                                             overview popularity  \
# 0  Taisto Kasurinen is a Finnish coal miner whose...   0.823904
# 1  An episode in the life of Nikander, a garbage ...    0.47445
# 2  It's Ted the Bellhop's first night on the job....      1.698
# 3  While racing to a boxing match, Frank, Mike, J...    1.32287
# ...

# %% [markdown]
# #### Question 19. Basic filtering and column selection
# Get the "budget" and "revenue" columns, and keep movies whose budget and revenue are larger than 10000
#
# __Hint.__ Use Pandas' df.loc[:, [COLUMNS TO EXTRACT]] command to get specific columns
# __Hint.__ You can filter rows using local operators as explained here (https://towardsdatascience.com/8-ways-to-filter-pandas-dataframes-d34ba585c1b8)

# %%
# QUESTION IN THIS CELL #
df_movies_filtered = None  # Put the filtered movies in this variable


# THE FOLLOWING CODE IS FOR CHECKING CORRECTNESS OF YOUR CODE
# If your code is correct, you will get (5570, 2) from the code below 
# That means 5570 movies match with your criteria, and you selected two columns
print(df_movies_filtered.shape)
import plotly.express as px
px.scatter(df_movies_filtered, x="revenue", y="budget").show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-136-1ead96201b93> in <module>
#       6 # If your code is correct, you will get (5570, 2) from the code below
#       7 # That means 5570 movies match with your criteria, and you selected two columns
# ----> 8 print(df_movies_filtered.shape)
#       9 import plotly.express as px
#      10 px.scatter(df_movies_filtered, x="revenue", y="budget").show()
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# #### Question 20. Calculate Correlation
# Calculate the Pearson correlation coefficient of budget and revenue, and report the coefficient.
#
# __Hint.__ Use numpy's corrcoef method as we did in the tutorial 9-10

# %%
# QUESTION IN THIS CELL #

import numpy as np
r =  None  # Put the Pearson correlation coefficient value in r

# THE FOLLOWING CODE IS FOR CHECKING CORRECTNESS OF YOUR CODE
# If your code is correct, you will get 0.7360150840672284 as the Pearson correlation coefficient
print(r)
# Out:
# None

# %% [markdown]
# ---
# ### Play Tennis Dataset
# To practice how to use contingency table for categorical values, we will use the toy dataset of Play Tennis example.

# %%
df_tennis = pd.read_csv("tennis.csv")
df_tennis.head()
# Out:
#     outlook  temp humidity  windy play
# 0     sunny   hot     high  False   no
# 1     sunny   hot     high   True   no
# 2  overcast   hot     high  False  yes
# 3     rainy  mild     high  False  yes
# 4     rainy  cool   normal  False  yes

# %% [markdown]
# #### Question 21. Calculating Association between Outlook and Play columns
# Let's calculate Cramer's V coefficient for `outlook` and `play` columns
#
# __Step 1.__ Create a contingency table of the two columns (using "crosstab" method of Pandas)
# __Step 2.__ Calculate Cramer's V coefficient as we did in the tutorial 9-10 (you can use one of the compact versions)

# %%
# QUESTION IN THIS CELL #

''' Step 1. Create a contingency table of outlook and play columns '''
ct_outlook_play = None  # Put the contingency table (including margins) in ct_outlook_play

# THE FOLLOWING CODE IS FOR CHECKING CORRECTNESS OF YOUR CODE
# If your code is correct, you will get the following result
# play      no  yes  All
# outlook               
# overcast   0    4    4
# rainy      2    3    5
# sunny      3    2    5
# All        5    9   14
print(ct_outlook_play)
# Out:
# None

# %%
# QUESTION IN THIS CELL #

''' Step 2. Calculate Cramer's V coefficient '''
cramer_v = None  # Put the cramer's V coefficient in this variable 

# THE FOLLOWING CODE IS FOR CHECKING CORRECTNESS OF YOUR CODE
# If your code is correct, you will get the following result
# Cramer's V:  0.5033222956847166
print("Cramer's V: ", cramer_v)
# Out:
# Cramer's V:  None

# %% [markdown]
# ---
# ## Part 2. Extra Question (25pts)
#
#
# ### E.g. Causal Model of group project stress
# To give an example, I created a hypothetical causal model that depicts how a wide range of causes affect the level of stress that students feel from group projects.
# ![image.png](attachment:4e858c76-bcea-4504-b541-cec3be1c9cda.png)
#
# #### Level 1. Association
# - How do the three factors (F,G,H) contribute to Group Project Stress (I)?
# - How are the three factors (A,B,C) collected at the beginning of the course correlated with the perceived workload (F)?
# - How are the two factors (C,D) correlated with the the group dynamics (G)?
# - How is the factor E correlated with the factor H (to what extent students like their project topics at the end of the course)?
#
# #### Level 2. Intervention
# - What if the professor assign members for each group to have the similar level of motivation (C) and # of courses being taken (A)? Will it affect the workload and group dynamics?
# - What if the professor set the expectation higher / lower? Will if affect the workload?
# - What if the professor ask students to choose project topics that every group member like?
#
# #### Level 3. Counterfactuals
# - Was there any other causes that affect Group Project Stress?
# - Do Workload (F) and Group Dynamics (G) affect how much students like their topics (H)?
# - What if collect MBTI results from students and see how it affects group dynamics (G)?
#
# #### Potential Product/Service Idea
# I propose PGM (Project Group Matcher) service that analyzes various factors of students that might affect group dynamics and workload of group projects. PGM predicts the level of stress that each group will experience throughout the course, and also recommends the best possible group arrangements and the level of expectations.
# (I skipped the UI drawing, but it might look like a dashboard + recommended group setup)
#
# ---
# ### Your Task: Causal Model of Losing / Gaining Weights
# - Imagine that you need to create an application that helps people lose / gain weights.
#
# - Draw a graph diagram of causal analysis containing at least three potential factors (as we saw in the lecture slide page 17 - Causal Analysis in Design Process) that affect losing / gaining weights. (paste the image into a markdown cell of this Notebook; if you attach an image file, make sure the image file is submitted together)
#
# - Assuming that you have sufficient amount of data for the factors you chose, describe at least one question per each ladder of causation (Page 28 of the lecture slide week 9-10).
#
# - Briefly explain how your application would help people lose / gain weights with one rough sketch and textual description (<200 characters)
