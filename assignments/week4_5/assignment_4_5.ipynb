# %% [markdown]
# # Week4-5 Assignments
# Week4 assignments consist of two parts (1: Knowledge check, 2:Coding exercise). At the end of part 2 there is one challenge question.
#
# ## How to Make Your Answers
# - You must carefully read cells containing "# QUESTION IN THIS CELL #". In those cells, you must complete certain variables / methods / cell following the instruction.
# - If you have any question or found bugs, please post it on the Q&A board of KLMS or send me an email (takyeonlee@kaist.ac.kr).

# %% [markdown]
# # Part 1. Knowledge Check
# - Before answering these questions, make sure you watched the corresponding lecture and tutorial videos.
# - Carefully read questions in comments, and put your answers in `answer_N` variables (where N=0,1,2,...).

# %%
# QUESTION IN THIS CELL #
''' Question 1. Which of the following statements is NOT true about data visualization?   
   1. DataVis transforms symbolic data into visual marks
   2. Communication is not always the top priority of data visualization
   3. The first step of the double diamond model for datavis is EDA 
   4. DataVis leverages cognitive power and working memory of human mind 
'''
answer_1 = None # Remove None and put your answer 1,2,3, or 4

# %%
# QUESTION IN THIS CELL #
''' Question 2. What does EDA stand for?
'''
answer_2 = None # Remove None and put your answer as text value (i.e. "_YOUR_ANSWER")

# %%
# QUESTION IN THIS CELL #
''' Question 3. Which of the following task is the LEAST relevant to EDA?
   1. Data Cleaning and Transformation
   2. Making and testing hypothesis
   3. Trial-and-errors of drawing charts
   4. Communicating insights with viewers via infographics
'''
answer_3 = None # Remove None and put your answer 1,2,3, or 4

# %%
# QUESTION IN THIS CELL #
''' Question 4-6. Fill the blanks in the following text
   [__Q4__] usually aims to visualize continuous data that has an inherent spatial 
   position. On the other hand, [__Q5__] visualizes abstract variables whose 
   relationship is not well understood. In order to communicate insights and messages 
   with viewers, [__Q6__] is often studied by graphic designers.  
'''
answer_4 = None # Remove None and put your answer as text value (i.e. "_YOUR_ANSWER")
answer_5 = None # Remove None and put your answer as text value (i.e. "_YOUR_ANSWER")
answer_6 = None # Remove None and put your answer as text value (i.e. "_YOUR_ANSWER")

# %%
# QUESTION IN THIS CELL #
''' Question 7. Who invented line, bar, and pie charts? Hint. The inventor was also
    a secret agent.
'''
answer_7 = None # Remove None and put your answer as text value (i.e. "_YOUR_ANSWER")

# %%
# QUESTION IN THIS CELL #
''' Question 8. Dr. John Snow is famous for identifying the source of a cholera outbreak. 
    What was the core medium of his method? Use a single word.  
'''
answer_8 = None # Remove None and put your answer as text value (i.e. "_YOUR_ANSWER")

# %%
# QUESTION IN THIS CELL #
''' Question 9. Minard's flow map of Napoleon's campaign is packed with lots of 
    information. Which visual encoding did he use in order to 
    visually separate the two flows (i.e. marching forward and retreating back)? 
    Use a single word. 
'''
answer_9 = None # Remove None and put your answer as text value (i.e. "_YOUR_ANSWER")

# %%
# QUESTION IN THIS CELL #
''' Question 10. Bertin's theory "visual langauge as a sign system" implies that there
    are two steps of transformation between sender and receiver. What are they?  
'''
answer_10 = ["", ""] # Put your answers as a list of two text values (i.e. ["in", "out"])

# %%
# QUESTION IN THIS CELL #
''' Question 11. According to Bertin, there are three signfields in graphics. 
    What are they? 
'''
answer_11 = ["", "", ""] # Put your answers as a list of three text values (i.e. ["in", "between", "out"])

# %%
# QUESTION IN THIS CELL #
''' Question 12. Which of the following task is NOT true about the visual encoding?
   1. Position is the best encoding for every data type
   2. Length, Angle, Slope, Area, and Volume are only effectve for quantitative values
   3. Every color-related encoding is useful only for ordered values
   4. Shape is a somewhat effective encoding for nominals, but still not the best option
'''
answer_12 = None # Remove None and put your answer 1,2,3, or 4

# %%
# QUESTION IN THIS CELL #
''' Question 13-17. Fill the blanks in the following text
    [__Q13__] is an effective visual encoding only for showing exact values. In 
    contrast, [__Q14__] is strong at visualizing both exact values and comparing 
    ratios. That is why [__Q15__] is one of the most widely used charts. 
    Area and Hue are both strong at [__Q16__]. Text is suitable for all three tasks
    (i.e. exact values, comparing ratios, drawing attention), but its main drawback
    is [__Q17__]

'''
answer_13 = None # Remove None and put your answer as text value (i.e. "_YOUR_ANSWER")
answer_14 = None # Remove None and put your answer as text value (i.e. "_YOUR_ANSWER")
answer_15 = None # Remove None and put your answer as text value (i.e. "_YOUR_ANSWER")
answer_16 = None # Remove None and put your answer as text value (i.e. "_YOUR_ANSWER")
answer_17 = None # Remove None and put your answer as text value (i.e. "_YOUR_ANSWER")

# %%
# QUESTION IN THIS CELL #
''' Question 18. Which of the folling is not a valid way to increase the data-ink 
                ratio of a bar chart?
   1. Remove backgrounds
   2. Remove borders
   3. Remove legends and unnecessary text
   4. Reduce the number of color variations
   5. Flatten 3D into 2D by removing shadows 
   6. Use lighter colors for bars
   7. Remove text styles (e.g. bold faces)
   8. Remove axis and grid lines as much as possible
   9. Place value labels within bars 
'''
answer_18 = None # Remove None and put your answer 1,2,3...

# %%
# QUESTION IN THIS CELL #
''' Question 19. Which of the following is not an issue of chart junks? 
   1. Statistical integrity
   2. Memorability
   3. Interpretability
   4. Overuse of space and ink
'''
answer_19 = None # Remove None and put your answer 1,2,3, or 4

# %% [markdown]
# This is the end of Part 1. Knowledge Check.
#
# ---

# %% [markdown]
# # Part 2. Coding Exercise
# - You must carefully read cells containing "# QUESTION IN THIS CELL #". In those cells, you must complete certain methods.
# - Other cells are provided to give you instructions or help testing your code.
# - In this assignment, you can import a limited set of libraries:
#   - Any basic module of the Python are allowed
#   - Libraries for statistical analysis (e.g. `numpy`, `pandas`, `sklearn`) are **NOT** allowed.
#   - Other than `plotly`, **NO** other visualization libaries (e.g. `matlplotlib`, `seaborn`, `ggplot`) are allowed.
# - Cells often rely on outcomes of the prior cells. Make sure you have executed *code* cells prior to the one that you are working on. If you are experiencing weird bugs, try clearing all outputs (Edit > Clear All Output) and run from the beginning (Run > Run All Cells).

# %% [markdown]
# ## Dataset (fifa.csv)
# - Make sure you have "fifa.csv" (provided along with this Notebook on KLMS), put it in the same folder with this Notebook.
# - The datasset represents five countries FIFA ranking (ordinal) for each date. Note that the rankings are currently text values (i.e. surrounded by single quotes)

# %%
# EXECUTE THIS CELL TO LOAD THE DATASET #
with open("fifa.csv","r") as csvFile:
    header = next(csvFile).strip().split(",")
    records = [r.strip().split(",") for r in csvFile]
print (header)
print (records[:5])

# An output of this cell must look like
# ['Date', 'ARG', 'BRA', 'ESP', 'FRA', 'GER', 'ITA']
# [['1993-08-08', '5.0', '8.0', '13.0', '12.0', '1.0', '2.0'], ['1993-09-23', '12.0', '1.0', '14.0', '7.0', '5.0', '2.0'], ['1993-10-22', '9.0', '1.0', '7.0', '14.0', '4.0', '3.0'], ['1993-11-19', '9.0', '4.0', '7.0', '15.0', '3.0', '1.0'], ['1993-12-23', '8.0', '3.0', '5.0', '15.0', '1.0', '2.0']]

# %% [markdown]
# ### Question 20. Convert Data Types and Transforming Nested-List to Column Dictionary
# Most descriptive statistics techniques are done on individual columns. To make descriptive statistics easy, let's create a dictionary of columns from the records (i.e. nested-list). Yes, we have done that many times in the previous assignment and tutorials. By the way, you also need to convert rankings into integers.

# %%
# COMPLETE THIS CELL #
''' This method accepts two parameters: 
        ct: A list of column titles
        rs: A list of records
    It must return a dictionary whose keys are column titles, 
      and values are lists of values of corresponding columns
    NOTE. Except the Date column, values must be converted to int. To convert text of floating numbers into int, 
    see this post (https://stackoverflow.com/questions/1841565/valueerror-invalid-literal-for-int-with-base-10)
'''
def makeColumnDictionary(ct, rs):
    # COMPLETE THIS METHOD #
    pass

# %%
# This cell is given to help you test the above method. 
colDict = makeColumnDictionary(header, records)
print (colDict['ARG'][:3])

# Output of this cell must like
# [5, 12, 9]

# %% [markdown]
# ### Question 21. Quick draw with raw data
# The dataset is ready to draw a chart without further transformation. Let's create a scatterplot (x:Date; y:ranking of six countries) Your code must draw charts like below.
# ![image.png](attachment:3b169e6f-bd53-4e6c-bb66-79e4f8133c9d.png)

# %%
# COMPLETE THIS CELL #
''' This cell draws a scatterplot
        x:     Date
        y:     Rankings of the six countries
        color: Unique color per country
'''
import plotly.express as px  # Use Plotly Express library
# COMPLETE THIS CELL (Don't need to create a method. Just draw it) #

# %% [markdown]
# ### Question 22. Finding facts from raw data
# The timeline chart is quite useful to find some interesting facts. Find at least five facts.
#   **E.g.** Germany had bad years 2005-2006, but got back to the top rank around 2015.
# [Hint] The scatterplot is crowded with too many dots. Click the country codes on the right side to toggle countries.

# %%
# QUESTION IN THIS CELL #
''' Question 22. Find five facts from the above scatterplot.
'''
answer_22 = ["FINDING 1", "FINDING 2", "FINDING 3", "FINDING 4", "FINDING 5"]

# %% [markdown]
# The scatterplot was effective to see historical trends. However, the chart has many limitations. For example, you cannot answer higher-level questions such as,
#   - Which country was the best / worst over the entire history / within a specific timespan?
#
# One way to answer the question is comparing distributions of ranking. Let's do that in the following two questions.

# %% [markdown]
# ### Question 23. Roll Up Dataset
# While column dictionaries are convenient for analyzing individual columns, a lot of Plotly's charting methods require a single dataset containing items for encoding channels (E.g. `country` for `color` encoding; `ranking` for `x-axis` encoding; etc). This is a data transformation called **roll up**. The reverse is called **pivot** ![image.png](attachment:82fe7268-0136-45cf-866c-1700fc925a54.png)

# %%
# COMPLETE THIS CELL #
''' This method rolls up a column dictionary. It accepts three parameters
        cDic: A dictionary to be rolled up
        key:  The key value for the keys of cDic (e.g. country)
        val:  The key value for the values of cDic (e.g. ranking)
    It must return a new dictionary containing two items
        {key} : A list of keys of cDic
        {val} : A list of corresponding values of cDic
    For instance, rollUpFifa(colDict, 'country', 'ranking') should return 
        { 
            'country': ['ARG',"ARG','ARG','BRA',...],
            'ranking': [3,3,2,1,...]
        }
    To give another example, rollUpFifa(colDict, 'aaa', 'bbb') should return 
        { 
            'aaa': ['ARG',"ARG','ARG','BRA',...],
            'bbb': [3,3,2,1,...]
        }
'''
def rollUpFifa(cDic, key, val):
    # COMPLETE THIS METHOD #
    pass

# %%
# This cell is given to help you test the above method.
# Since the original data is too big to manually check, let's take the first three items per country
testData = { 
    c:colDict[c][:3]
    for c in header
}
rd = rollUpFifa(testData,'country','ranking')
print(rd)

# Output of this cell must look like
# {'country': ['ARG', 'ARG', 'ARG', 'BRA', 'BRA', 'BRA', 'ESP', 'ESP', 'ESP', 'FRA', 'FRA', 'FRA', 'GER', 'GER', 'GER', 'ITA', 'ITA', 'ITA'], 'ranking': [5, 12, 9, 8, 1, 1, 13, 14, 7, 12, 7, 14, 1, 5, 4, 2, 2, 3]}

# %% [markdown]
# ### Question 24. Box Plot
# Since we have a rolled up dictionary now, we can draw box plots and other advanced charts that Plotly offers!
# In this question, you need to figure out how to draw the following chart based on the Plotly documentation.
# ![image.png](attachment:e341df6f-4645-4e05-b068-57dfb60651c7.png)
#
# First, take a look [Plotly Box Plots](https://plotly.com/python/box-plots/) page that shows a variety of box plots. By combining different parameters you will be able to draw the above box plot.
#
# **Hint.** You might need to use `x`,`y`,`color`, and `points` parameters

# %%
# QUESTION IN THIS CELL #

import plotly.graph_objects as go
import plotly.express as px

rolledUpDictionary = rollUpFifa(colDict,'country', 'ranking')

# COMPLETE THIS CELL BY ADDING CODE LINES BELOW

# %% [markdown]
# ### Question 25. Finding facts from box plot
# The box plot shows distributions of how each country performed in the overall time period. List at least three facts you can find.
# **E.g.** France had the worst max ranking (27th) among the six countries.
# **Hint.** Hover your mouse cursor over a box plot. You will be able to see what each element of box plot means. For example, the center line is NOT 'mean' but 'median'. Each box is from the first to the third quartile (i.e. 25% to 75% percentiles). The range of whisker is called 'fence'
# ![image.png](attachment:02b4b68c-c788-4094-b5b1-ba51d55147a5.png)

# %%
# QUESTION IN THIS CELL #
''' Question 25. Find three facts from the above scatterplot.
'''
answer_25 = ["FINDING 1", "FINDING 2", "FINDING 3"]

# %% [markdown]
# ---

# %% [markdown]
# # Challenge 1. Do your own analysis
# ### Iris Dataset

# %% [markdown]
# Download the **Iris dataset**, which is one of the most famous dataset, from [this Kaggle page](https://www.kaggle.com/uciml/iris). Put it in the same folder with this Notebook file.
# ![image.png](attachment:47af50fe-ad22-4155-8ad4-4379546992a0.png)
#
# Your task is to explore the dataset by drawing any number of charts. You might have noticed there are so many reports of the dataset on the Internet including the `code` tab of the Kaggle page. I won't stop you copying good ideas from existing reports. However, try to build your own composition.
#
# This question does not have any correct or wrong answers. But we will use the following evaluation criteria
#   - **Diversity of Chart Types.** You must use at least three different types of chart in your analysis
#   - **Quality of Narrative.** Your analysis MUST NOT be an enumeration of charts. Your analysis MUST have `Markdown` cells between `Code` cells (like our course tutorials have).

# %%
# START YOUR ANALYSIS FROM THIS CELL #

# %% [markdown]
# # Well done! This is the end of the Assignment 4.
# - Save this Notebook file and submit via KLMS
# - Before submitting, clean run the entire Notebook in two steps
#     1. (Edit > Clear All Outputs) Reset the outputs of the entire notebook
#     2. (Run > Run All Cells) Check every cell runs without any error message or incorrect behavior
# - Before submitting, provide your name and student ID below

# %%
# COMPLETE THIS CELL #
yourName = "NAME HERE"
yourStudentID = "YOUR ID HERE"
