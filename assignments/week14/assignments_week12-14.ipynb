# %% [markdown]
# # Week 12-14 Assignments
# Part 1 the regular questions section is total 100 pts. Part 2 contains an extra question at the end, which is worth 25% of the regular questions.
#
# ## How to Make Your Answers
# - You must carefully read cells containing "# QUESTION IN THIS CELL #". In those cells, you must complete certain variables / methods / cell following the instruction.
# - If you have any question or found bugs, please post it on the Q&A board of KLMS or send me an email (takyeonlee@kaist.ac.kr).
#
# ## Make sure your notebook runs without error
# - After finishing the entire notebook, use (Kernel > Restart Kernel and Run All Cells) and __make sure all the cells run without any syntax error__.

# %% [markdown]
# ---
# ## Part 1. Regular Questions (100pts)
# - Now part 1 covers both knowledge check and coding exercise.
# - Before answering these questions, make sure you watched the corresponding lecture and tutorial videos.
# - Carefully read questions in comments, and put your answers in `answer_N` variables (where N=0,1,2,...).

# %% [markdown]
# ### Knowledge Check of A/B Test

# %%
# QUESTION IN THIS CELL #
''' Question 1-17. Indicate whether the following statements are True or False  '''

# STATEMENT. Journey map is represented as graph where nodes represent key states
#                and edges represent possible transition between states
answer_1 = None  # Replace none with True or False


# STATEMENT. Unlike undirected graphs, directed graphs can represent which state
#                the flow starts from / ends at.
answer_2 = None  # Replace none with True or False


# STATEMENT. Edges of undirected graphs cannot have weights
answer_3 = None  # Replace none with True or False


# STATEMENT. Journey map is usually represented with directed graphs 
answer_4 = None  # Replace none with True or False


# STATEMENT. A specific user/customers on journey map cannot exist at multiple 
#            at the same time
answer_5 = None  # Replace none with True or False


# STATEMENT. The first step of journey map analysis is defining a small number of 
#            key phases and their in-bound / out-bound paths
answer_6 = None  # Replace none with True or False


# STATEMENT. On a journey map, user segments are defined based user's previous and
#            current states
answer_7 = None  # Replace none with True or False


# STATEMENT. User/Customer segments are good target of causal analysis 
#            and/or interventions
answer_8 = None  # Replace none with True or False


# STATEMENT. Journey analysis is a linear process so that we have to stick with 
#            the four steps - mostly without repetitions              
answer_9 = None  # Replace none with True or False


# STATEMENT. Cohort analysis is an additonal analysis you can run on existing 
#            journey maps
answer_10 = None  # Replace none with True or False


# STATEMENT. Cohort is a group of people sharing common characteristics EXCLUDING
#            which state they are at on the journey map
answer_11 = None  # Replace none with True or False


# STATEMENT. While journey map focuses on monitoring current state of everyone,
#            cohort analysis compare long-term behaviors of multiple groups 
answer_12 = None  # Replace none with True or False


# STATEMENT. It is recommended to define cohorts as specific as possible 
answer_13 = None  # Replace none with True or False


# STATEMENT. Napoleon's march by Minard is a good example of cohort analysis 
answer_14 = None  # Replace none with True or False


# STATEMENT. Funnel is a partial view of a journey map, focusing on linear progression
#            and # or % of people proceeded to the next stage
answer_15 = None  # Replace none with True or False


# STATEMENT. Since funnel deals with the entire population, there is no easy way to 
#            compare multiple groups of people with funnels. 
answer_16 = None  # Replace none with True or False


# STATEMENT. Sankey diagram is slighly more expressive than funnel as it tracks
#            both diverging and converging paths.
answer_17 = None  # Replace none with True or False

# %% [markdown]
# ---
# ### Extra Question (25pts)
# At Facebook, any ads on timeline has the icon of three dots at the top-right corner. If you click it there are seven actions for the ad, as in the figure below.
#
# ![image.png](attachment:1c312997-fb16-475c-b43f-b3f5937956c2.png)
#
# Your task is to try explore all of them, and draw a user journey map using any graphic tool (e.g. powerpoint, figma). __Attach a screenshot of your map in the following cell__
