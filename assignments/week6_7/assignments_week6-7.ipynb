# %% [markdown]
# # Week6-7 Assignments
# Week6-7 assignments consist of knowledge check and one challenge question.
#
# ## How to Make Your Answers
# - You must carefully read cells containing "# QUESTION IN THIS CELL #". In those cells, you must complete certain variables / methods / cell following the instruction.
# - If you have any question or found bugs, please post it on the Q&A board of KLMS or send me an email (takyeonlee@kaist.ac.kr).

# %% [markdown]
# # Knowledge Check Questions
# - Before answering these questions, make sure you watched the corresponding lecture and tutorial videos.
# - Carefully read questions in comments, and put your answers in `answer_N` variables (where N=0,1,2,...).

# %%
# QUESTION IN THIS CELL #
''' Question 1. To create meaningful visualizations with 1D Nominal columns, 
    you need to do ______ first.    
'''
answer_1 = "YOUR ANSWER"

# %%
# QUESTION IN THIS CELL #
''' Question 2. Which of the following statement is NOT true? 
    1. 1D quantitative column can be binned into histogram in order 
        draw meaningful charts 
    2. Descriptive statistics can be directly visualized from a 
        quantititative column
    3. EDA mostly start with multivariate analysis because a single multi-variate
        chart enables many analytic tasks. 
    4. Finding interesting pair of columns is a core activity of EDA
'''
answer_2 = None  # Replace None with you answer as a number

# %%
# QUESTION IN THIS CELL #
''' Question 3. Which of the following statement is NOT true? 
    1. 2D nominal columns require frequency counting to draw meaningful charts 
    2. 2D nominal x quantitative combinations can be directly drawn without preprocessing
    3. Box plot is a good way to visualize marginal distributions because it allows 
        precise comparison
    4. Any combination of three columns can be drawn in a 3D space consists 
        of (x, y, z-axis). 
'''
answer_3 = None  # Replace None with you answer as a number

# %%
# QUESTION IN THIS CELL #
''' Question 4. Let's say you have six columns containing all quantitative values. 
    You want to QUICKLY find correlations between columns. 
    What is the best charting technique for your analysis?  
'''
answer_4 = "YOUR ANSWER"

# %%
# QUESTION IN THIS CELL #
''' Question 5. In what situation grouped bar charts are better than 
        stacked bar charts? Why do you think so? Explain with less than 100 characters.
'''
answer_5 = "YOUR ANSWER"

# %%
# QUESTION IN THIS CELL #
''' Question 6. Why is line chart a bad design for uneven-spaced time series? 
        Explain with less than 100 characters.
'''
answer_6 = "YOUR ANSWER"

# %%
# QUESTION IN THIS CELL #
''' Question 7. For Part-to-Whole relationships, explain why bar charts 
        are better than pie charts. Explain three reasons within 500 characters. 
'''
answer_7 = "YOUR ANSWER"

# %%
# QUESTION IN THIS CELL #
''' Question 8-9. Describe two example situations where Likert scale data from a survey 
        is ordinal / interval.
'''
answer_8 = "DESCRIBE AN EXAMPLE SITUATION OF ORDINAL"
answer_9 = "DESCRIBE AN EXAMPLE SITUATION OF INTERVAL"

# %%
# QUESTION IN THIS CELL #
''' Question 10. For a series of ordinal values collected from survey, 
    describe between-group and within-group comparisons within 100 characters.
'''
answer_10 = "YOUR ANSWER"

# %%
# QUESTION IN THIS CELL #
''' Question 11. Bar charts are extremely versatile (i.e. effective for a wide range situations),
        but it has one disadvantage. Describe it within 50 characters.
'''
answer_11 = "YOUR ANSWER"

# %%
# QUESTION IN THIS CELL #
''' Question 12. What are common weaknesses of advanced charts such as treemap, sankey diagram, 
        force-directed layout, and wordcloud. Describe within 100 characters.  
'''
answer_12 = "YOUR ANSWER"

# %%
# QUESTION IN THIS CELL #
''' Question 13. List the three steps of Ben Shneiderman's mantra for visual information seeking
'''
answer_13 = ["STEP1", "STEP2", "STEP3"]

# %%
# QUESTION IN THIS CELL #
''' Question 14. Briefly explain what "Brushing & linking" is. Describe within 100 characters.
'''
answer_14 = "YOUR ANSWER"

# %%
# QUESTION IN THIS CELL #
''' Question 15. The following statments are about the double-diamond model for data visualization.
                 Which one is NOT TRUE?
        1. The first diamond is EDA process, the second is data storytelling and communication. 
        2. The first diamond is mainly for the analysts themselves. The second diamond is for other people.
        3. The two diamonds can be separately done by data scientists and designers at the same time
'''
answer_15 = None  # Replace None with you answer as a number

# %%
# QUESTION IN THIS CELL #
''' Question 16. The figure below represents number of gold/silver/bronze medals won by 
                 three countries. Report at least one finding from the figure according to 
                 the guidelines of the week 7 lecture. [Hint] You might need to calculate using
                 the numbers in the data table. 
'''
answer_16 = None  # Replace None with you answer as a number

# %% [markdown]
# ![image.png](attachment:83e658e9-29a9-4be8-986e-56a3cda65951.png)

# %%
# QUESTION IN THIS CELL #
''' Question 17. There is a rule of reporting multiple charts - "Avoid dramatic changes of 
        column encoding". Find (or Draw) two examples of good and bad cases. Each example must 
        contain two visualizations shown in sequence. 
        
        Attach an image of the two examples in the below markdown cell. 
        (You can paste clipboard or use <img> tag) 
'''

# %% [markdown]
# Attach image(s) of the two examples in this cell. You can paste clipboard or embed image file(s)
# using `<img>` tag.

# %%
# QUESTION IN THIS CELL #
''' Question 18. What are three key elements of data storytelling?
'''
answer_18 = ["E1", "E2", "E3"]

# %%
# QUESTION IN THIS CELL #
''' Question 19. What can be achieved by combining each pair of key elements of data storytelling?
        Note. Ordering doesn't matter.  
'''
answer_19 = ["E1", "E2", "E3"]

# %%
# QUESTION IN THIS CELL #
''' Question 20. "In listening to stories we tend to suspend disbelief in order to be entertained"
        This quote supports a specific goal of data storytelling. What is the goal?
'''
answer_20 = "YOUR ANSWER"

# %% [markdown]
# # Challenge Question.

# %% [markdown]
# Pick an existing product (or service) that employs data visualization as part of its functionality.
#
# - Provide at least three images (screenshots or photos) of it.
#
#   **[ATTACH IMAGES HERE]**
#
# - Analyze the goal(s) of the product's data visualization.
#     E.g. Facilitating self reflection of ___ and giving motivations for ___
#     E.g. Helping users to make quick decisions of ___ in the context of ___
#     E.g. Providing feeling of achievements of ___
#     E.g. Simulating What-if scenarios of ___
#     E.g. Enabling users to find insights of ___ so that users can ___
#
#   **[DESCRIBE THE GOAL(S) HERE]**
#
# - How would you redesign the data visualization to better satisfy user needs?
#   Provide a rough sketch or low-fidelity UI mock-up. Describe your design briefly within 200 characters.
#
#   **[REDESIGN HERE]**

# %% [markdown]
# # Well done! This is the end of the Assignment 6-7.
# - Save this Notebook file and submit via KLMS
# - Before submitting, clean run the entire Notebook in two steps
#     1. (Edit > Clear All Outputs) Reset the outputs of the entire notebook
#     2. (Run > Run All Cells) Check every cell runs without any error message or incorrect behavior
# - Before submitting, provide your name and student ID below

# %%
# COMPLETE THIS CELL #
yourName = "NAME HERE"
yourStudentID = "YOUR ID HERE"
